# %%
import pandas as pd

data = pd.read_csv('spx.csv',index_col=0,parse_dates=True)
series = data['SPX']
series
# Out:
# Date
# 1990-02-01     328.79
# 1990-02-02     330.92
# 1990-02-05     331.85
# 1990-02-06     329.66
# 1990-02-07     333.75
#                ...
# 2011-10-10    1194.89
# 2011-10-11    1195.54
# 2011-10-12    1207.25
# 2011-10-13    1203.66
# 2011-10-14    1224.58
# Name: SPX, Length: 5472, dtype: float64

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv('spx.csv',index_col=0,parse_dates=True)
series = data['SPX']
fig = plt.figure(figsize=(10,5))
axes = fig.add_subplot(1,1,1)
series.plot.line(ax=axes,style='k-')
_ = axes.set_title('Important dates in the 2008-2009 financial crisis')

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv('spx.csv',index_col=0,parse_dates=True)
series = data['SPX']
fig = plt.figure(figsize=(10,5))
axes = fig.add_subplot(1,1,1)
series.plot.line(ax=axes,style='k-')
_ = axes.set_title('Important dates in the 2008-2009 financial crisis')
axes.set_xlim('2007-01-01','2011-01-01')
axes.set_ylim([600,1600])
# Out:
# (600.0, 1600.0)

# %%
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime

data = pd.read_csv('spx.csv',index_col=0,parse_dates=True)
series = data['SPX']
fig = plt.figure(figsize=(10,5))
axes = fig.add_subplot(1,1,1)
crisis_data = [
    (datetime(2007, 10, 11),'Peak of bull market'),
    (datetime(2008, 3, 12),'Bear Stearns Fails'),
    (datetime(2008, 9, 15), 'Lehman Bankruptcy')
]
for date, label in crisis_data:
    axes.annotate(label,
                  xy=(date,series[date]+25),
                  xytext=(date,series[date]+225),
                  arrowprops=dict(facecolor='red',headwidth=4,width=2,headlength=4),
                  horizontalalignment='left',
                  verticalalignment='top'
                  )
series.plot.line(ax=axes,style='k-')
_ = axes.set_title('Important dates in the 2008-2009 financial crisis')

axes.set_xlim(datetime(2007,1,1),'2011-01-01')
axes.set_ylim([600, 1850])
# Out:
# (600.0, 1850.0)
