# %%
import pandas as pd

df1 = pd.read_csv('new各鄉鎮市區人口密度.csv')
df1

# %%
import pandas as pd

df1 = pd.read_csv('new各鄉鎮市區人口密度.csv')
display(df1)
type(df1.style)

# %%
import pandas as pd

df1 = pd.read_csv('new各鄉鎮市區人口密度.csv')
display(df1)
def format1(value:int):
    return f"第{value}號"
df1.style\
.format(precision=2,thousands=',',decimal='.')\
.format_index(format1)

# %%
df1 = pd.read_csv('new各鄉鎮市區人口密度.csv')
display(df1)
df1.style\
.format(precision=2,thousands=',',decimal='.')\
.format_index(lambda value:f'第{value}號')

# %%
import numpy as np
weather_df = pd.DataFrame(np.random.rand(10,2)*5,
                        index=pd.date_range(start="2021-01-01", periods=10),
                        columns=["Tokyo", "Taipei"])

# %%
weather_df.style\
.set_caption('Weather Conditions')\
.format_index(lambda v:v.strftime("%A"))
# Out:
# <style type="text/css">
# </style>
# <table id="T_378ca">
#   <caption>Weather Conditions</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_378ca_level0_col0" class="col_heading level0 col0" >Tokyo</th>
#       <th id="T_378ca_level0_col1" class="col_heading level0 col1" >Taipei</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_378ca_level0_row0" class="row_heading level0 row0" >Friday</th>
#       <td id="T_378ca_row0_col0" class="data row0 col0" >1.434207</td>
#       <td id="T_378ca_row0_col1" class="data row0 col1" >2.674823</td>
#     </tr>
#     <tr>
#       <th id="T_378ca_level0_row1" class="row_heading level0 row1" >Saturday</th>
#       <td id="T_378ca_row1_col0" class="data row1 col0" >4.722015</td>
#       <td id="T_378ca_row1_col1" class="data row1 col1" >3.260105</td>
#     </tr>
#     <tr>
#       <th id="T_378ca_level0_row2" class="row_heading level0 row2" >Sunday</th>
#       <td id="T_378ca_row2_col0" class="data row2 col0" >3.745074</td>
#       <td id="T_378ca_row2_col1" class="data row2 col1" >3.487405</td>
#     </tr>
#     <tr>
#       <th id="T_378ca_level0_row3" class="row_heading level0 row3" >Monday</th>
#       <td id="T_378ca_row3_col0" class="data row3 col0" >2.334200</td>
#       <td id="T_378ca_row3_col1" class="data row3 col1" >4.700225</td>
#     </tr>
#     <tr>
#       <th id="T_378ca_level0_row4" class="row_heading level0 row4" >Tuesday</th>
#       <td id="T_378ca_row4_col0" class="data row4 col0" >0.112745</td>
#       <td id="T_378ca_row4_col1" class="data row4 col1" >2.169428</td>
#     </tr>
#     <tr>
#       <th id="T_378ca_level0_row5" class="row_heading level0 row5" >Wednesday</th>
#       <td id="T_378ca_row5_col0" class="data row5 col0" >1.649809</td>
#       <td id="T_378ca_row5_col1" class="data row5 col1" >4.998823</td>
#     </tr>
#     <tr>
#       <th id="T_378ca_level0_row6" class="row_heading level0 row6" >Thursday</th>
#       <td id="T_378ca_row6_col0" class="data row6 col0" >3.968165</td>
#       <td id="T_378ca_row6_col1" class="data row6 col1" >2.730495</td>
#     </tr>
#     <tr>
#       <th id="T_378ca_level0_row7" class="row_heading level0 row7" >Friday</th>
#       <td id="T_378ca_row7_col0" class="data row7 col0" >4.361237</td>
#       <td id="T_378ca_row7_col1" class="data row7 col1" >4.962626</td>
#     </tr>
#     <tr>
#       <th id="T_378ca_level0_row8" class="row_heading level0 row8" >Saturday</th>
#       <td id="T_378ca_row8_col0" class="data row8 col0" >3.165043</td>
#       <td id="T_378ca_row8_col1" class="data row8 col1" >1.579499</td>
#     </tr>
#     <tr>
#       <th id="T_378ca_level0_row9" class="row_heading level0 row9" >Sunday</th>
#       <td id="T_378ca_row9_col0" class="data row9 col0" >3.057945</td>
#       <td id="T_378ca_row9_col1" class="data row9 col1" >2.147755</td>
#     </tr>
#   </tbody>
# </table>

# %%
weather_df.style\
.set_caption('Weather Conditions')\
.format_index(lambda v:v.strftime("%a"))\
.background_gradient(vmin=1,vmax=5)
# Out:
# <style type="text/css">
# #T_07307_row0_col0 {
#   background-color: #efe9f3;
#   color: #000000;
# }
# #T_07307_row0_col1 {
#   background-color: #94b6d7;
#   color: #000000;
# }
# #T_07307_row1_col0 {
#   background-color: #034a74;
#   color: #f1f1f1;
# }
# #T_07307_row1_col1 {
#   background-color: #549cc7;
#   color: #f1f1f1;
# }
# #T_07307_row2_col0 {
#   background-color: #1e80b8;
#   color: #f1f1f1;
# }
# #T_07307_row2_col1 {
#   background-color: #3790c0;
#   color: #f1f1f1;
# }
# #T_07307_row3_col0 {
#   background-color: #b4c4df;
#   color: #000000;
# }
# #T_07307_row3_col1 {
#   background-color: #034c78;
#   color: #f1f1f1;
# }
# #T_07307_row4_col0 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_07307_row4_col1 {
#   background-color: #c2cbe2;
#   color: #000000;
# }
# #T_07307_row5_col0 {
#   background-color: #e4e1ef;
#   color: #000000;
# }
# #T_07307_row5_col1 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_07307_row6_col0 {
#   background-color: #0872b1;
#   color: #f1f1f1;
# }
# #T_07307_row6_col1 {
#   background-color: #8fb4d6;
#   color: #000000;
# }
# #T_07307_row7_col0 {
#   background-color: #046096;
#   color: #f1f1f1;
# }
# #T_07307_row7_col1 {
#   background-color: #023a5b;
#   color: #f1f1f1;
# }
# #T_07307_row8_col0 {
#   background-color: #60a1ca;
#   color: #f1f1f1;
# }
# #T_07307_row8_col1 {
#   background-color: #e7e3f0;
#   color: #000000;
# }
# #T_07307_row9_col0 {
#   background-color: #6da6cd;
#   color: #f1f1f1;
# }
# #T_07307_row9_col1 {
#   background-color: #c4cbe3;
#   color: #000000;
# }
# </style>
# <table id="T_07307">
#   <caption>Weather Conditions</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_07307_level0_col0" class="col_heading level0 col0" >Tokyo</th>
#       <th id="T_07307_level0_col1" class="col_heading level0 col1" >Taipei</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_07307_level0_row0" class="row_heading level0 row0" >Fri</th>
#       <td id="T_07307_row0_col0" class="data row0 col0" >1.434207</td>
#       <td id="T_07307_row0_col1" class="data row0 col1" >2.674823</td>
#     </tr>
#     <tr>
#       <th id="T_07307_level0_row1" class="row_heading level0 row1" >Sat</th>
#       <td id="T_07307_row1_col0" class="data row1 col0" >4.722015</td>
#       <td id="T_07307_row1_col1" class="data row1 col1" >3.260105</td>
#     </tr>
#     <tr>
#       <th id="T_07307_level0_row2" class="row_heading level0 row2" >Sun</th>
#       <td id="T_07307_row2_col0" class="data row2 col0" >3.745074</td>
#       <td id="T_07307_row2_col1" class="data row2 col1" >3.487405</td>
#     </tr>
#     <tr>
#       <th id="T_07307_level0_row3" class="row_heading level0 row3" >Mon</th>
#       <td id="T_07307_row3_col0" class="data row3 col0" >2.334200</td>
#       <td id="T_07307_row3_col1" class="data row3 col1" >4.700225</td>
#     </tr>
#     <tr>
#       <th id="T_07307_level0_row4" class="row_heading level0 row4" >Tue</th>
#       <td id="T_07307_row4_col0" class="data row4 col0" >0.112745</td>
#       <td id="T_07307_row4_col1" class="data row4 col1" >2.169428</td>
#     </tr>
#     <tr>
#       <th id="T_07307_level0_row5" class="row_heading level0 row5" >Wed</th>
#       <td id="T_07307_row5_col0" class="data row5 col0" >1.649809</td>
#       <td id="T_07307_row5_col1" class="data row5 col1" >4.998823</td>
#     </tr>
#     <tr>
#       <th id="T_07307_level0_row6" class="row_heading level0 row6" >Thu</th>
#       <td id="T_07307_row6_col0" class="data row6 col0" >3.968165</td>
#       <td id="T_07307_row6_col1" class="data row6 col1" >2.730495</td>
#     </tr>
#     <tr>
#       <th id="T_07307_level0_row7" class="row_heading level0 row7" >Fri</th>
#       <td id="T_07307_row7_col0" class="data row7 col0" >4.361237</td>
#       <td id="T_07307_row7_col1" class="data row7 col1" >4.962626</td>
#     </tr>
#     <tr>
#       <th id="T_07307_level0_row8" class="row_heading level0 row8" >Sat</th>
#       <td id="T_07307_row8_col0" class="data row8 col0" >3.165043</td>
#       <td id="T_07307_row8_col1" class="data row8 col1" >1.579499</td>
#     </tr>
#     <tr>
#       <th id="T_07307_level0_row9" class="row_heading level0 row9" >Sun</th>
#       <td id="T_07307_row9_col0" class="data row9 col0" >3.057945</td>
#       <td id="T_07307_row9_col1" class="data row9 col1" >2.147755</td>
#     </tr>
#   </tbody>
# </table>

# %%
weather_df.index
# Out:
# DatetimeIndex(['2021-01-01', '2021-01-02', '2021-01-03', '2021-01-04',
#                '2021-01-05', '2021-01-06', '2021-01-07', '2021-01-08',
#                '2021-01-09', '2021-01-10'],
#               dtype='datetime64[ns]', freq='D')
