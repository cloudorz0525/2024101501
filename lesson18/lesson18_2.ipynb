# %%
import os
def merge_data(station_paths:list[str],info:str):
    print(station_paths)
    print("===============")
    print(info)

current_folder = os.getcwd()
stations_folder = os.path.join(current_folder,'stations')
csv_abs_files = []
for filename in os.listdir(stations_folder):
    if '每日各站' in filename:
        csv_abs_files.append(os.path.join(stations_folder,filename))

info_path = os.path.join(stations_folder,'台鐵車站資訊.csv')


merge_data(csv_abs_files,info_path)
# Out:
# ['/workspaces/2024101501/lesson18/stations/每日各站進出站人數2023.csv', '/workspaces/2024101501/lesson18/stations/每日各站進出站人數2021.csv', '/workspaces/2024101501/lesson18/stations/每日各站進出站人數2020.csv', '/workspaces/2024101501/lesson18/stations/每日各站進出站人數20190423-20191231.csv', '/workspaces/2024101501/lesson18/stations/每日各站進出站人數2022.csv']
# ===============
# /workspaces/2024101501/lesson18/stations/台鐵車站資訊.csv

# %%
import os
import pandas as pd
from pandas import DataFrame

def merge_data(station_paths:list[str],info:str)->DataFrame:
    '''
    傳出所有的資料
    '''
    info_df = pd.read_csv(info)
    merge_datas = []
    for sta_path in station_paths:
        station_df = pd.read_csv(sta_path)
        merge_df = pd.merge(station_df, info_df,how='left',left_on='staCode',right_on='stationCode')
        merge_datas.append(merge_df)
    return pd.concat(merge_datas)


current_folder = os.getcwd()
stations_folder = os.path.join(current_folder,'stations')
csv_abs_files = []
for filename in os.listdir(stations_folder):
    if '每日各站' in filename:
        csv_abs_files.append(os.path.join(stations_folder,filename))

info_path = os.path.join(stations_folder,'台鐵車站資訊.csv')


df = merge_data(csv_abs_files,info_path)
df
# Out:
#        trnOpDate  staCode  gateInComingCnt  gateOutGoingCnt  stationCode  \
# 0       20230101      900             8030             8241          900
# 1       20230101      910             1017             1326          910
# 2       20230101      920             1400             1705          920
# 3       20230101      930             3558             4398          930
# 4       20230101      940             1509             1815          940
# ...          ...      ...              ...              ...          ...
# 86547   20221231     7360             3984             3893         7360
# 86548   20221231     7361               92              115         7361
# 86549   20221231     7362              131              159         7362
# 86550   20221231     7380              494              426         7380
# 86551   20221231     7390              313              274         7390
#
#       stationName name                                  stationAddrTw  \
# 0              基隆   基隆                                    基隆市仁愛區港西街5號
# 1              三坑   三坑                             基隆市仁愛區德厚里龍安街 206 號
# 2              八堵   八堵                             基隆市暖暖區八南里八堵路 142 號
# 3              七堵   七堵                               基隆市七堵區長興里東新街 2 號
# 4              百福   百福                          基隆市七堵區堵南里明德三路 1 之 1 號
# ...           ...  ...                                            ...
# 86547          瑞芳   瑞芳                            新北市瑞芳區龍潭里明燈路三段 82 號
# 86548         海科館  海科館                                      基隆市中正區長潭里
# 86549         八斗子  八斗子  新北市瑞芳區建基路2段121號隔壁 砂子里省道臺 2 線 (與新北市瑞芳區交界處、無站房)
# 86550         四腳亭  四腳亭                              新北市瑞芳區吉慶里中央路 65 號
# 86551          暖暖   暖暖                              基隆市暖暖區暖暖里暖暖街 51 號
#
#         stationTel                 gps haveBike
# 0      02-24263743  25.13411 121.73997        Y
# 1      02-24230289  25.12305 121.74202        Y
# 2      02-24560841  25.10843 121.72898        Y
# 3      02-24553426  25.09294 121.71415        Y
# 4      02-24528372  25.07795 121.69379        N
# ...            ...                 ...      ...
# 86547  02-24972033  25.10861 121.80596        Y
# 86548  02-24972033  25.13754 121.79997        N
# 86549  02-24972033  25.13545 121.80261        N
# 86550  02-24579346  25.10283 121.76192        N
# 86551  02-24972033  25.10224 121.74048        N
#
# [406761 rows x 11 columns]

# %%
import os
import pandas as pd
from pandas import DataFrame

def merge_data(station_paths:list[str],info:str)->DataFrame:
    '''
    傳出所有的資料
    '''
    info_df = pd.read_csv(info)
    merge_datas = []
    for sta_path in station_paths:
        station_df = pd.read_csv(sta_path)
        merge_df = pd.merge(station_df, info_df,how='left',left_on='staCode',right_on='stationCode')
        merge_datas.append(merge_df)
    return pd.concat(merge_datas)


current_folder = os.getcwd()
stations_folder = os.path.join(current_folder,'stations')
csv_abs_files = []
for filename in os.listdir(stations_folder):
    if '每日各站' in filename:
        csv_abs_files.append(os.path.join(stations_folder,filename))

info_path = os.path.join(stations_folder,'台鐵車站資訊.csv')


df = merge_data(csv_abs_files,info_path)
df1 = df[['trnOpDate','gateInComingCnt','gateOutGoingCnt','name','stationAddrTw','haveBike']]

# %%
df1.columns = ['日期','進站人數','出站人數','站名','地址','youbike']
df1
# Out:
#              日期  進站人數  出站人數   站名  \
# 0      20230101  8030  8241   基隆
# 1      20230101  1017  1326   三坑
# 2      20230101  1400  1705   八堵
# 3      20230101  3558  4398   七堵
# 4      20230101  1509  1815   百福
# ...         ...   ...   ...  ...
# 86547  20221231  3984  3893   瑞芳
# 86548  20221231    92   115  海科館
# 86549  20221231   131   159  八斗子
# 86550  20221231   494   426  四腳亭
# 86551  20221231   313   274   暖暖
#
#                                                   地址 youbike
# 0                                        基隆市仁愛區港西街5號       Y
# 1                                 基隆市仁愛區德厚里龍安街 206 號       Y
# 2                                 基隆市暖暖區八南里八堵路 142 號       Y
# 3                                   基隆市七堵區長興里東新街 2 號       Y
# 4                              基隆市七堵區堵南里明德三路 1 之 1 號       N
# ...                                              ...     ...
# 86547                            新北市瑞芳區龍潭里明燈路三段 82 號       Y
# 86548                                      基隆市中正區長潭里       N
# 86549  新北市瑞芳區建基路2段121號隔壁 砂子里省道臺 2 線 (與新北市瑞芳區交界處、無站房)       N
# 86550                              新北市瑞芳區吉慶里中央路 65 號       N
# 86551                              基隆市暖暖區暖暖里暖暖街 51 號       N
#
# [406761 rows x 6 columns]

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 406761 entries, 0 to 86551
# Data columns (total 6 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   日期       406761 non-null  int64
#  1   進站人數     406761 non-null  int64
#  2   出站人數     406761 non-null  int64
#  3   站名       406761 non-null  object
#  4   地址       406761 non-null  object
#  5   youbike  406761 non-null  object
# dtypes: int64(3), object(3)
# memory usage: 21.7+ MB

# %%
df1['日期'] = pd.to_datetime(df1['日期'].astype(str))
# Out:
# /tmp/ipykernel_32295/2470081304.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['日期'] = pd.to_datetime(df1['日期'].astype(str))

# %%
df1['youbike'] = df1['youbike'].map({'Y':1,'N':0})
# Out:
# /tmp/ipykernel_32295/1675081192.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['youbike'] = df1['youbike'].map({'Y':1,'N':0})

# %%
df2 = df1.sort_values(by='日期')
df3 = df2.set_index('日期')

# %%
def first_third(val:str)->str:
    return val[:3]

df3['地址'].map(first_third)
# Out:
# 日期
# 2019-04-23    臺南市
# 2019-04-23    彰化縣
# 2019-04-23    南投縣
# 2019-04-23    南投縣
# 2019-04-23    南投縣
#              ...
# 2023-12-31    彰化縣
# 2023-12-31    彰化縣
# 2023-12-31    彰化縣
# 2023-12-31    臺中市
# 2023-12-31    基隆市
# Name: 地址, Length: 406761, dtype: object

# %%
df3['縣市'] = df3['地址'].map(lambda v:v[:3])

# %%
df3
# Out:
#              進站人數   出站人數   站名                  地址  youbike   縣市
# 日期
# 2019-04-23   2516   2667   永康  臺南市永康區埔園里中山路 459 號        1  臺南市
# 2019-04-23     19     21   源泉  彰化縣二水鄉合興村英義路 (無站房)        0  彰化縣
# 2019-04-23     70     63   濁水   南投縣名間鄉濁水村車站路 15 號        0  南投縣
# 2019-04-23      8     12   龍泉  南投縣集集鎮隘寮村龍泉巷 (無站房)        0  南投縣
# 2019-04-23    299    127   集集   南投縣集集鎮吳厝里民生路 75 號        0  南投縣
# ...           ...    ...  ...                 ...      ...  ...
# 2023-12-31  19617  16699   彰化    彰化縣彰化市長樂里三民路 1 號        1  彰化縣
# 2023-12-31   1864   1532   花壇  彰化縣花壇鄉花壇村中正路 370 號        1  彰化縣
# 2023-12-31   1315   1100   大村  彰化縣大村鄉過溝村福進路 100 號        0  彰化縣
# 2023-12-31    781    778  頭家厝     臺中市潭子區頭張東路43巷8號        0  臺中市
# 2023-12-31    576    447   暖暖   基隆市暖暖區暖暖里暖暖街 51 號        0  基隆市
#
# [406761 rows x 6 columns]

# %%
def first_third(val:str)->str:
    return val[:3]

df3['地址'].map(first_third)
# Out:
# 日期
# 2019-04-23    臺南市
# 2019-04-23    彰化縣
# 2019-04-23    南投縣
# 2019-04-23    南投縣
# 2019-04-23    南投縣
#              ...
# 2023-12-31    彰化縣
# 2023-12-31    彰化縣
# 2023-12-31    彰化縣
# 2023-12-31    臺中市
# 2023-12-31    基隆市
# Name: 地址, Length: 406761, dtype: object

# %%
df3['縣市'] = df3['地址'].map(lambda v:v[:3])

# %%
df3["年度"] = df3.index.strftime('%Y')
df3['年月'] = df3.index.strftime('%Y-%m')

# %%
df4 = df3.reindex(columns=['縣市','年度','年月','站名','進站人數','出站人數','youbike'])
df4
# Out:
#              縣市    年度       年月   站名   進站人數   出站人數  youbike
# 日期
# 2019-04-23  臺南市  2019  2019-04   永康   2516   2667        1
# 2019-04-23  彰化縣  2019  2019-04   源泉     19     21        0
# 2019-04-23  南投縣  2019  2019-04   濁水     70     63        0
# 2019-04-23  南投縣  2019  2019-04   龍泉      8     12        0
# 2019-04-23  南投縣  2019  2019-04   集集    299    127        0
# ...         ...   ...      ...  ...    ...    ...      ...
# 2023-12-31  彰化縣  2023  2023-12   彰化  19617  16699        1
# 2023-12-31  彰化縣  2023  2023-12   花壇   1864   1532        1
# 2023-12-31  彰化縣  2023  2023-12   大村   1315   1100        0
# 2023-12-31  臺中市  2023  2023-12  頭家厝    781    778        0
# 2023-12-31  基隆市  2023  2023-12   暖暖    576    447        0
#
# [406761 rows x 7 columns]

# %%
df4.to_csv('全台火車進出站資訊.csv')
