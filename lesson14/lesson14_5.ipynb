# %%
import numpy as np
import pandas as pd

scores = np.random.randint(50,101,size=(50, 5))
df1 = pd.DataFrame(scores,
             columns=['國文', '英文', '數學', '地理', '歷史'],
             index = range(1,51))
df1

# %%
df1.index.name = '學號'
df1.columns.name = "科目"

# %%
df1.loc[1].sum()
# Out:
# np.int64(314)

# %%
sum = df1.sum(axis=1)

average = sum / 5

# %%
df1['總分'] = sum
df1['平均'] = average
df1
# Out:
# 科目   國文   英文   數學   地理   歷史   總分    平均
# 學號
# 1    60   50   70   52   82  314  62.8
# 2    97   75   93   68   63  396  79.2
# 3    77   69   53   65   91  355  71.0
# 4    66   90   82   81   73  392  78.4
# 5    95   86   87   71   77  416  83.2
# 6    77   52   50   50  100  329  65.8
# 7    50  100   50  100   82  382  76.4
# 8    82   66   58   52   85  343  68.6
# 9    77   95   76   68   78  394  78.8
# 10   88   68   73   55   74  358  71.6
# 11   70   52   56   59   99  336  67.2
# 12   67   81   98   80   87  413  82.6
# 13  100   66   96   72   55  389  77.8
# 14   72   77   56   87   66  358  71.6
# 15   83   98   76   94   50  401  80.2
# 16   95   60   67   70   70  362  72.4
# 17   78   60   65   77   77  357  71.4
# 18   75   78   56   87   65  361  72.2
# 19   75   86   86   82   59  388  77.6
# 20   63   69   97   89   70  388  77.6
# 21   57   65   70   72   75  339  67.8
# 22   77  100   93   64   61  395  79.0
# 23   94   99   80   97   58  428  85.6
# ...
